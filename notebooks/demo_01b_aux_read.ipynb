# %%
from datetime import datetime
from function.auxvars import AuxPaths, AuxDataLoader

paths = AuxPaths(
    canopy_height_h5=r"G:\data\CanopyHeight\CH.h5",
    igbp_dir=r"G:\data\MCD12C1 CMG\01Degree\h5",
    agb_dir=r"G:\data\ESACCI AGB\h5",
    lai_dir=r"G:\data\GLASS LAI\01nc",
    fvc_dir=r"G:\data\GLASS FVC\01nc",
    lst_dir=r"G:\data\MOD11C1 CMG LST\01h5",
)

loader = AuxDataLoader(paths)
aux = loader.load_all_for_date(datetime(2015, 7, 1))

print(aux.hveg.shape, aux.agb.shape, aux.lai.shape, aux.fvc.shape, aux.lst_k.shape)
print(list(aux.igbp.keys())[:5], " ... ", len(aux.igbp))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from datetime import datetime
# ----> 2 from function.auxvars import AuxPaths, AuxDataLoader
#       4 paths = AuxPaths(
#       5     canopy_height_h5=r"G:\data\CanopyHeight\CH.h5",
#       6     igbp_dir=r"G:\data\MCD12C1 CMG\01Degree\h5",
#    (...)     10     lst_dir=r"G:\data\MOD11C1 CMG LST\01h5",
#      11 )
#      13 loader = AuxDataLoader(paths)
#
# ModuleNotFoundError: No module named 'function'
